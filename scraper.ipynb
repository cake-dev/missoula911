# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# replace the input below with the copy result from a google map search.

# %%
import re
import json


def extract_store_info(text):
    stores = []
    lines = text.split('\n')
    
    name = None
    for i, line in enumerate(lines): # match on the rating line or No reviews
        if re.match(r'\d+\.\d+\(\d+\)', line) or 'No reviews' in line:
            name = lines[i-1].strip()
        elif 'Storage' in line and name: # modify this with the type of store on the address line
            address = re.search(r'\d+.*?(?=\s*$)', line)
            if address:
                stores.append({
                    "name": name,
                    "address": address.group().strip()
                })
                name = None
    
    return stores


# Google maps copy paste results input text
input_text = """
Results
Canyon RV, Boat & Self Storage
4.7(12)
Self-storage facility ·  · 984 Deer Creek Rd
Open 24 hours · (406) 317-2110

Website


Directions
 
Copperstone Stor-All
4.5(80)
Self-storage facility ·  · 8700 Roller Coaster Rd
Open ⋅ Closes 11 PM · (406) 728-7867

Website


Directions
 
Missoula Storage City
4.9(10)
Self-storage facility · 5500 Aviation Way
Open ⋅ Closes 10 PM · (406) 926-0574

Website


Directions
 
Onsite services
Grant Creek Self Storage
4.3(42)
Self-storage facility ·  · 2405 Michael Rd
Closed ⋅ Opens 10 AM Thu · (406) 540-6468

Website


Directions
 
Onsite services
Riverside Storage Missoula, LLC
4.3(34)
Self-storage facility ·  · 3645 Clark Fork Way
Open ⋅ Closes 10 PM · (406) 541-7586

Website


Directions
The Storage Center, LLC
4.5(16)
Self-storage facility ·  · 1870 S Reserve St
Open ⋅ Closes 9:30 PM · (406) 926-3228

Website


Directions
All Star Self Storage
4.7(25)
Self-storage facility ·  · 4645 Harlequin Ct
(406) 541-4645

Website


Directions
 
Onsite services
Copperstone Stor-All
4.5(80)
Self-storage facility ·  · 8700 Roller Coaster Rd
Open ⋅ Closes 11 PM · (406) 728-7867

Website


Directions
 
Onsite services
University Storage
4.7(68)
Self-storage facility ·  · 7480 MT-200 E
Open ⋅ Closes 10 PM · (406) 214-3801

Website


Directions
Sentinel Storage
1.0(1)
Self-storage facility ·  · 1140 E Broadway St
Open 24 hours · (406) 530-9274

Website


Directions
 
Onsite services
Mvli Properties / Storage, Llc
1.0(1)
Self-storage facility · Biggers Ln


Directions
Westview Public Mini-Storage
3.6(49)
Storage facility ·  · 3500 Schramm St
Closed ⋅ Opens 10 AM Thu · (406) 549-3111

Website


Directions
 
Onsite services
Mullan Road Storage
4.6(14)
Self-storage facility ·  · 2855 Mullan Rd
(406) 721-8710

Website


Directions
Expressway Self Storage
4.4(44)
Self-storage facility ·  · 4949 Storehouse Way
Closed ⋅ Opens 9 AM Thu · (406) 728-6565

Website


Directions
Mr. T's Self Storage
4.2(53)
Self-storage facility ·  · 5075 Expressway
Closed ⋅ Opens 8 AM Thu · (406) 541-7777

Website


Directions
Closed ⋅ Opens 9:30 AM Thu · (406) 303-4164

Website


Directions
S & S Payless Storage
5.0(2)
Storage · 3806 South Ave W
(406) 549-1234


Directions
Ace Mini Warehouse
4.6(9)
Self-storage facility · 1203 Montana St
Closed ⋅ Opens 11 AM Thu · (406) 549-2161


Directions
Aa Mini Storage
4.7(3)
Storage · 1300 Wyoming St
Closed ⋅ Opens 9 AM Thu · (406) 543-7140

Website


Directions
Centergate Mini Storage
4.5(2)
Storage facility ·  · 710 Cooper St
Closed ⋅ Opens 9 AM Thu · (406) 549-3929

Website


Directions
Broadway Storage
3.7(9)
Storage facility · 1150 E Broadway St
Closed ⋅ Opens 7:53 AM Thu · (406) 721-0485

Website


Directions
 
Onsite services
Rent-A-Space
3.5(6)
Self-storage facility ·  · 2319 Mount Ave
Closed ⋅ Opens 8 AM Thu · (406) 728-6228

Website


Directions

    """

places = extract_store_info(input_text)

# # Write to JSON file
# with open('cannabis_stores.json', 'w') as f:
#     json.dump(stores, f, indent=2)

# print(f"Extracted information for {len(stores)} stores and saved to cannabis_stores.json")

# %%
len(places)
# Out:
# 11

# %%
places
# Out:
# [{'name': 'Westview Public Mini-Storage', 'address': '3500 Schramm St'},
#  {'name': 'Broadway Storage', 'address': '116 W Spruce St'},
#  {'name': 'Montana Street Storage', 'address': '1522 Montana St'},
#  {'name': 'Affordable Storage', 'address': '1914 Kemp St'},
#  {'name': 'Access Storage Mullan', 'address': '8315 Mullan Rd'},
#  {'name': 'CMI Mini-Storage', 'address': '2401 W Sussex Ave'},
#  {'name': 'A A able All Storage', 'address': '2122 South Ave W'},
#  {'name': 'S & S Payless Storage', 'address': '3806 South Ave W'},
#  {'name': 'Aa Mini Storage', 'address': '1300 Wyoming St'},
#  {'name': 'Centergate Mini Storage', 'address': '710 Cooper St'},
#  {'name': 'Broadway Storage', 'address': '1150 E Broadway St'}]

# %%
places_df = pd.DataFrame(places)
# append 'Missoula' to all addresses
places_df['address'] = places_df['address'] + ', Missoula, MT'

# %%
places_df.address
# Out:
# 0        3500 Schramm St, Missoula, MT
# 1        116 W Spruce St, Missoula, MT
# 2        1522 Montana St, Missoula, MT
# 3           1914 Kemp St, Missoula, MT
# 4         8315 Mullan Rd, Missoula, MT
# 5      2401 W Sussex Ave, Missoula, MT
# 6       2122 South Ave W, Missoula, MT
# 7       3806 South Ave W, Missoula, MT
# 8        1300 Wyoming St, Missoula, MT
# 9          710 Cooper St, Missoula, MT
# 10    1150 E Broadway St, Missoula, MT
# Name: address, dtype: object

# %%
# drop rows without a full address or with AM or PM in the address
places_df = places_df[~places_df['address'].str.contains('AM|PM')]
places_df = places_df.reset_index(drop=True)

# %%
places_df = places_df[~places_df['address'].str.contains('\(|hours|\)')]
places_df = places_df.reset_index(drop=True)

# %%
# # drop odd rows starting with row 1
# places_df = places_df.drop(places_df.index[1::2])
# places_df = places_df.reset_index(drop=True)

# %%
# drop rows with duplicate addresses
places_df = places_df.drop_duplicates(subset='address', keep='first')
places_df = places_df.reset_index(drop=True)
places_df
# Out:
#                                                  name  \
# 0                         Emerald Liquor & Wine Store
# 1                          Magic Diamond Liquor Store
# 2                          Magic Diamond Liquor Store
# 3                                      Grizzly Liquor
# 4                                       Krisco Liquor
# 5                   Lucky Lil's Casino & Liquor Store
# 6                 Magic Diamond Casino & Liquor Store
# 7                 Magic Diamond Casino & Liquor Store
# 8                 Lucky Diamond Casino & Liquor Store
# 9   Magic Diamond Sports Bar, Liquor Store and Casino
# 10                             Big Head's Bottle Shop
# 11                            Missoula Wine Merchants
# 12                                               None
#
#                                  address
# 0        4951 N Reserve St, Missoula, MT
# 1   3420 Mullan Rd Suite C, Missoula, MT
# 2       1210 W Broadway St, Missoula, MT
# ...

# %%
# change the store with None name to 'Casino Liquor Store'
places_df.loc[places_df['name'].isnull(), 'name'] = 'Casino Liquor Store'
places_df.address
# Out:
# 0          4951 N Reserve St, Missoula, MT
# 1     3420 Mullan Rd Suite C, Missoula, MT
# 2         1210 W Broadway St, Missoula, MT
# 3            110 W Spruce St, Missoula, MT
# 4          1300 S Reserve St, Missoula, MT
# 5             2021 Brooks St, Missoula, MT
# 6             2230 Brooks St, Missoula, MT
# 7          900 E Broadway St, Missoula, MT
# 8             3700 Brooks St, Missoula, MT
# 9          4875 N Reserve St, Missoula, MT
# 10        3106 W Broadway St, Missoula, MT
# 11         311 N Higgins Ave, Missoula, MT
# 12        680 SW Higgins Ave, Missoula, MT
# Name: address, dtype: object

# %% [markdown]
# ##### Google Places API

# %%
import requests
def get_place_info(query, api_key):
# Base URL
  base_url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
# Parameters in a dictionary
  params = {
   "input": query,
   "inputtype": "textquery",
   "fields": "formatted_address,name,business_status,place_id",
   "key": api_key,
  }
# Send request and capture response
  response = requests.get(base_url, params=params)
# Check if the request was successful
  if response.status_code == 200:
    return response.json()
  else:
    return None

# %%
api_key = "AIzaSyDKQnvdjvooPj4yS7_m6x3EyOxsJxcKnZs"
query = "Dispensary in Missoula, MT"
place_info = get_place_info(query, api_key)
if place_info is not None:
  print(place_info)
else:
  print("Failed to get a response from Google Places API")
# Out:
# {'candidates': [{'business_status': 'OPERATIONAL', 'formatted_address': '1001 N Russell St A, Missoula, MT 59802, United States', 'name': 'Bloom Weed Dispensary Missoula', 'place_id': 'ChIJsSYwAevPXVMRcInU-J59U54'}], 'status': 'OK'}
